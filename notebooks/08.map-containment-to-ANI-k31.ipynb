# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

sns.set_context("paper")
import matplotlib.ticker as ticker

from tqdm import tqdm # progress bars :)
tqdm.pandas()
from sklearn.metrics import r2_score
import scipy as sp

# %%
ka = pd.read_csv("gtdb-rs202.nucleotide-k31-scaled1000.prefetch.csv.gz")
ka.head()
# Out:
# /Users/tessa/opt/miniconda3/envs/2021-rank-compare-nb/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    intersect_bp   jaccard  max_containment  f_query_match  f_match_query  \
# 0         89000  0.009374         0.020213       0.017181       0.020213
# 1         87000  0.009257         0.019759       0.017119       0.019759
# 2       2434000  0.374462         0.552805       0.537188       0.552805
# 3         97000  0.010641         0.022030       0.020166       0.022030
# 4         85000  0.009328         0.019305       0.017730       0.019305
#
#    match match_filename                                         match_name  \
# 0    NaN     /dev/fd/63  GCF_006461405.1 Salmonella enterica strain=GSJ...
# 1    NaN     /dev/fd/63  GCF_003064405.1 Salmonella enterica subsp. ent...
# ...

# %%
ka['avg_containment_ani'] = ka[["query_ani", "match_ani"]].mean(axis=1)
ka['avg_containment'] = ka[["f_query_match", "f_match_query"]].mean(axis=1)
ka.head()
